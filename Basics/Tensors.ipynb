# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu121

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3050 Ti Laptop GPU'

# %%
a = torch.empty(2,3)  #allocates space in memory

# %%
type(a)
# Out:
# torch.Tensor

# %%
b = torch.zeros(2,3)
b
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand(2,3) #bw - and 1
# Out:
# tensor([[0.9649, 0.8923, 0.2601],
#         [0.8735, 0.0475, 0.3318]])

# %%
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %%
torch.tensor([[1,2,3],[1,2,3]])
# Out:
# tensor([[1, 2, 3],
#         [1, 2, 3]])

# %%
x = torch.tensor([[1,2,3],[1,2,3]])
x.shape
# Out:
# torch.Size([2, 3])

# %%
torch.empty_like(x)  #same shape
# Out:
# tensor([[0, 0, 0],
#         [0, 0, 0]])

# %%
torch.zeros_like(x) 
torch.ones_like(x)
# Out:
# tensor([[1, 1, 1],
#         [1, 1, 1]])

# %%
x
x.dtype
# Out:
# torch.int64

# %%
c = torch.tensor([1.0,2.0,3.0] , dtype = torch.int32)
d = torch.tensor([1,2,3] , dtype = torch.float32)

# %%
y = x.to(torch.float32)

# %%
torch.rand_like(y)
# Out:
# tensor([[0.2627, 0.0428, 0.2080],
#         [0.1180, 0.1217, 0.7356]])

# %% [markdown]
# Not really needed to write all the things

# %%
# inplace ops
'''
new tensors are formed when the operations are performed on existing vectors
so we use inplace
just use underscore 
m.relu_() like this
'''

# %% [markdown]
# copying a tensor

# %%
a = torch.rand(2,3)

# %%
b = a.clone()

# %%
id(a)
# Out:
# 2588492201824

# %%
id(b)
# Out:
# 2588347307152

# %% [markdown]
# operations on gpu

# %%
device = torch.device('cuda')

# %%
torch.rand((2,3),device = device)
# Out:
# tensor([[0.3563, 0.0303, 0.7088],
#         [0.2009, 0.0224, 0.9896]], device='cuda:0')

# %%
a = torch.rand(2,3)
a
# Out:
# tensor([[0.4440, 0.9478, 0.7445],
#         [0.4892, 0.2426, 0.7003]])

# %%
b = a.to(device)

# %%
b
# Out:
# tensor([[0.4440, 0.9478, 0.7445],
#         [0.4892, 0.2426, 0.7003]], device='cuda:0')

# %%
import time

# %%
size = 10000
matrix_cpu1 = torch.randn(size,size)
matrix_cpu2 = torch.randn(size,size)
start_time = time.time()
result_cpu = torch.matmul(matrix_cpu1 , matrix_cpu2)
cpu_time = time.time() - start_time
print(f"Time on CPU : {cpu_time: .4f} sec")

matrix_gpu1 = matrix_cpu1.to(device) 
matrix_gpu2 = matrix_cpu2.to(device) 
start_time = time.time()
torch.cuda.synchronize()
result_cpu = torch.matmul(matrix_cpu1 , matrix_cpu2)
gpu_time = time.time() - start_time
print(f"Time on GPU : {gpu_time: .4f} sec")
# Out:
# Time on CPU :  6.8254 sec
# Time on GPU :  7.0744 sec

# %%
#unsqueeze and squeeze 
# adds another dimension
